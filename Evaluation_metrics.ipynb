# %% [markdown]
# This notebook is used for the evaluation of the chosen metrics for the stylized images we produced with all the architectures.

# %%
# Initialize variables to store data
data_efficient = []
data_mobile = []
data_vgg = []

# directories for the three architectures
filename = ['./StylizedImages/Efficient/Metrics.txt','./StylizedImages/Mobile/Metrics.txt','./StylizedImages/Mobile/Metrics.txt']

filename_efficient = './StylizedImages/Efficient/Metrics.txt'
filename_mobile = './StylizedImages/Mobile/Metrics.txt'
filename_vgg = './StylizedImages/VGG/Metrics.txt'
# Open the text file for reading  
with open(filename_efficient, 'r') as file:
    entry = {}
    for line in file:
        line = line.strip()
        if line.startswith('Image and Style:'):
            entry['Image'] = line.split(':')[1].strip()
        elif line.startswith('SSIM Value:'):
            entry['SSIM Value'] = float(line.split(':')[1].strip())
        else:
            entry['Values'] = [float(value) for value in line.split()]
            data_efficient.append(entry)
            entry = {}
# Create a new list to store the extracted strings
image_strings = []

# Iterate through the original list
for element in data_efficient:
    if 'Image' in element:
        image_strings.append(element['Image'])


# Initialize a new list to store grouped elements
grouped_list_efficient = []

# Iterate through the input list
for i in range(0, len(data_efficient), 3):
    group = {}
    for j in range(3):
        if 'Image' in data_efficient[i + j]:
            group['Image'] = data_efficient[i + j]['Image']
            group['SSIM Value'] = data_efficient[i + j]['SSIM Value']
        if 'Values' in data_efficient[i + j]:
            if 'Values' not in group:
                group['Values'] = []
            group['Values'].extend(data_efficient[i + j]['Values'])
    grouped_list_efficient.append(group)

# Calculate averages of chi score
chi_values_list_efficient = []
for i in range (len(grouped_list_efficient)):
    #chi_values.append(grouped_list[i]['Values'])
    average = sum(grouped_list_efficient[i]['Values']) / len(grouped_list_efficient[i]['Values'])
    #print("Average Chi Value:", average)
    # Normalization of chi score
    average = 1/(1+average)
    #print("Normalized Average Chi Value:", average)
    chi_values_list_efficient.append(average)

# Iterate through the list
ssim_value_list_efficient = []
for item in data_efficient:
    if 'SSIM Value' in item:
        ssim_value = item['SSIM Value']
        
        # Print or use the extracted data as needed
        #print("SSIM Value:", ssim_value)
        ssim_value_list_efficient.append(ssim_value)

# Calculate an average combined score
average_score_efficient = []
for i in range(len(chi_values_list_efficient)):
    average_score_efficient.append( (chi_values_list_efficient[i] + ssim_value_list_efficient[i])/2);
    #print(average_score_efficient[i])
    






# Open the text file for reading  
with open(filename_mobile, 'r') as file:
    entry = {}
    for line in file:
        line = line.strip()
        if line.startswith('Image and Style:'):
            entry['Image'] = line.split(':')[1].strip()
        elif line.startswith('SSIM Value:'):
            entry['SSIM Value'] = float(line.split(':')[1].strip())
        else:
            entry['Values'] = [float(value) for value in line.split()]
            data_mobile.append(entry)
            entry = {}

# Initialize a new list to store grouped elements
grouped_list_mobile = []

# Iterate through the input list
for i in range(0, len(data_mobile), 3):
    group = {}
    for j in range(3):
        if 'Image' in data_mobile[i + j]:
            group['Image'] = data_mobile[i + j]['Image']
            group['SSIM Value'] = data_mobile[i + j]['SSIM Value']
        if 'Values' in data_mobile[i + j]:
            if 'Values' not in group:
                group['Values'] = []
            group['Values'].extend(data_mobile[i + j]['Values'])
    grouped_list_mobile.append(group)

# Calculate averages of chi score
chi_values_list_mobile = []
for i in range (len(grouped_list_mobile)):
    #chi_values.append(grouped_list[i]['Values'])
    average = sum(grouped_list_mobile[i]['Values']) / len(grouped_list_mobile[i]['Values'])
    #print("Average Chi Value:", average)
    # Normalization of chi score
    average = 1/(1+average)
    #print("Normalized Average Chi Value:", average)
    chi_values_list_mobile.append(average)

# Iterate through the list
ssim_value_list_mobile = []
for item in data_mobile:
    if 'SSIM Value' in item:
        ssim_value = item['SSIM Value']
        
        # Print or use the extracted data as needed
        #print("SSIM Value:", ssim_value)
        ssim_value_list_mobile.append(ssim_value)

# Calculate an average combined score
average_score_mobile =[]
for i in range(len(chi_values_list_mobile)):
    average_score_mobile.append( (chi_values_list_mobile[i] + ssim_value_list_mobile[i])/2);
    #print(average_score_mobile[i])






# Open the text file for reading  
with open(filename_vgg, 'r') as file:
    entry = {}
    for line in file:
        line = line.strip()
        if line.startswith('Image and Style:'):
            entry['Image'] = line.split(':')[1].strip()
        elif line.startswith('SSIM Value:'):
            entry['SSIM Value'] = float(line.split(':')[1].strip())
        else:
            entry['Values'] = [float(value) for value in line.split()]
            data_vgg.append(entry)
            entry = {}

# Initialize a new list to store grouped elements
grouped_list_vgg = []

# Iterate through the input list
for i in range(0, len(data_vgg), 3):
    group = {}
    for j in range(3):
        if 'Image' in data_vgg[i + j]:
            group['Image'] = data_vgg[i + j]['Image']
            group['SSIM Value'] = data_vgg[i + j]['SSIM Value']
        if 'Values' in data_vgg[i + j]:
            if 'Values' not in group:
                group['Values'] = []
            group['Values'].extend(data_vgg[i + j]['Values'])
    grouped_list_vgg.append(group)

# Calculate averages of chi score
chi_values_list_vgg = []
for i in range (len(grouped_list_vgg)):
    #chi_values.append(grouped_list[i]['Values'])
    average = sum(grouped_list_vgg[i]['Values']) / len(grouped_list_vgg[i]['Values'])
    #print("Average Chi Value:", average)
    # Normalization of chi score
    average = 1/(1+average)
    #print("Normalized Average Chi Value:", average)
    chi_values_list_vgg.append(average)

# Iterate through the list
ssim_value_list_vgg = []
for item in data_vgg:
    if 'SSIM Value' in item:
        ssim_value = item['SSIM Value']
        
        # Print or use the extracted data as needed
        #print("SSIM Value:", ssim_value)
        ssim_value_list_vgg.append(ssim_value)

# Calculate an average combined score
average_score_vgg =[]
for i in range(len(chi_values_list_vgg)):
    average_score_vgg.append( (chi_values_list_vgg[i] + ssim_value_list_vgg[i])/2);
    #print(average_score_vgg[i])



# Final evaluation, which architecture works best
First_Places = []
Second_Places = []
for i in range(len(image_strings)):
    value1 = average_score_vgg[i]
    value2 = average_score_mobile[i]
    value3 = average_score_efficient[i]

    if value1 > value2 and value1 > value3:
        print("For Image '"+image_strings[i]+f"' VGG has the largest score :{value1}.")
        First_Places.append("VGG")
        if value2 > value3:
            print("For Image '"+image_strings[i]+f"' Mobile has the second largest score :{value2}.")
            print()
            Second_Places.append("Mobile")
        else:
            print("For Image '"+image_strings[i]+f"' Efficient has the second largest score :{value3}.")
            print()
            Second_Places.append("Efficient")
            
    elif value2 > value1 and value2 > value3:
        print("For Image '"+image_strings[i]+f"' Mobile has the largest score :{value2}.")
        First_Places.append("Mobile")
        if value1 > value3:
            print("For Image '"+image_strings[i]+f"' VGG has the second largest score :{value1}.")
            print()
            Second_Places.append("VGG")
        else:
            print("For Image '"+image_strings[i]+f"' Efficient has the second largest score :{value3}.")
            print()
            Second_Places.append("Efficient")
    else:
        print("For Image '"+image_strings[i]+f"' Efficient has the largest score :{value3}.")
        First_Places.append("Efficient")
        if value1 > value2:
            print("For Image '"+image_strings[i]+f"' VGG has the second largest score :{value1}.")
            print()
            Second_Places.append("VGG")
        else:
            print("For Image '"+image_strings[i]+f"' Mobile has the second largest score :{value2}.")
            print()
            Second_Places.append("Mobile")
# Out:
# For Image 'Image1.jpgVasiliy_Kandinskiy_2.jpg' VGG has the largest score :0.15445208644986724.
# For Image 'Image1.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the second largest score :0.14152797880060694.
#
# For Image 'Image1.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.0720369916450846.
# For Image 'Image1.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.042579392087829196.
#
# For Image 'Image1.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.2834063955836779.
# For Image 'Image1.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.11348648966313205.
#
# For Image 'Image1.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.31227328728872195.
# For Image 'Image1.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.2865104337279266.
#
# For Image 'Image1.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the largest score :0.30164538697132204.
# For Image 'Image1.jpgVasiliy_Kandinskiy_9.jpg' VGG has the second largest score :0.2936765417809281.
#
# For Image 'Image10.jpgVasiliy_Kandinskiy_2.jpg' VGG has the largest score :0.21924501652641504.
# For Image 'Image10.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the second largest score :0.13018817271122465.
#
# For Image 'Image10.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.44152133155599216.
# For Image 'Image10.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.14850434616596137.
#
# For Image 'Image10.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.22975334834638406.
# For Image 'Image10.jpgVasiliy_Kandinskiy_74.jpg' Mobile has the second largest score :0.1424615884639399.
#
# For Image 'Image10.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the largest score :0.23649874360155326.
# For Image 'Image10.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the second largest score :0.2245085975295397.
#
# For Image 'Image10.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the largest score :0.31158429900287216.
# For Image 'Image10.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the second largest score :0.28205259389400394.
#
# For Image 'Image11.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.3184064635993836.
# For Image 'Image11.jpgVasiliy_Kandinskiy_2.jpg' VGG has the second largest score :0.07486967851290686.
#
# For Image 'Image11.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.28188834229634646.
# For Image 'Image11.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.07254376406648891.
#
# For Image 'Image11.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.20893553371950607.
# For Image 'Image11.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.10080064509476339.
#
# For Image 'Image11.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.23838226558947906.
# For Image 'Image11.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.0931355158707541.
#
# For Image 'Image11.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the largest score :0.27482067204468336.
# For Image 'Image11.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the second largest score :0.2720350722426764.
#
# For Image 'Image12.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.2572115244865837.
# For Image 'Image12.jpgVasiliy_Kandinskiy_2.jpg' VGG has the second largest score :0.06607175215920644.
#
# For Image 'Image12.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.18365987577824727.
# For Image 'Image12.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.07417053482257932.
#
# For Image 'Image12.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.24096776906804937.
# For Image 'Image12.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.08665585607105189.
#
# For Image 'Image12.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.4251082341479564.
# For Image 'Image12.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.22157370071230326.
#
# For Image 'Image12.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the largest score :0.39795739715087075.
# For Image 'Image12.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the second largest score :0.3871676867779649.
#
# For Image 'Image2.jpgVasiliy_Kandinskiy_2.jpg' VGG has the largest score :0.2147879194531528.
# For Image 'Image2.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the second largest score :0.1552060940304096.
#
# For Image 'Image2.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.10007279615793999.
# For Image 'Image2.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.0767935971806515.
#
# For Image 'Image2.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.28778178369518276.
# For Image 'Image2.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.10556178660350175.
#
# For Image 'Image2.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.3700192432770944.
# For Image 'Image2.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.35997134019647825.
#
# For Image 'Image2.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the largest score :0.4062576901211339.
# For Image 'Image2.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the second largest score :0.37649304800062167.
#
# For Image 'Image3.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.20398373487499435.
# For Image 'Image3.jpgVasiliy_Kandinskiy_2.jpg' VGG has the second largest score :0.10416432195071695.
#
# For Image 'Image3.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.09034779172518968.
# For Image 'Image3.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.053157151076177904.
#
# For Image 'Image3.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.2776920986092388.
# For Image 'Image3.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.09997327206392286.
#
# For Image 'Image3.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.3616458993376732.
# For Image 'Image3.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.2942605096708069.
#
# For Image 'Image3.jpgVasiliy_Kandinskiy_9.jpg' VGG has the largest score :0.40986983571527386.
# For Image 'Image3.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the second largest score :0.40576588829400045.
#
# For Image 'Image4.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.1285212362217646.
# For Image 'Image4.jpgVasiliy_Kandinskiy_2.jpg' VGG has the second largest score :0.11482787904441585.
#
# For Image 'Image4.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.28914021342834667.
# For Image 'Image4.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.16924652154314207.
#
# For Image 'Image4.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.30715144395769745.
# For Image 'Image4.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.13187465456563763.
#
# For Image 'Image4.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.38248453319018516.
# For Image 'Image4.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.21307504426410567.
#
# For Image 'Image4.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the largest score :0.3718686995798022.
# For Image 'Image4.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the second largest score :0.3705749934755673.
#
# For Image 'Image5.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.13271390877874717.
# For Image 'Image5.jpgVasiliy_Kandinskiy_2.jpg' VGG has the second largest score :0.08031024932012765.
#
# For Image 'Image5.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.22718372211539814.
# For Image 'Image5.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.08505019620039675.
#
# For Image 'Image5.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.2105335022096955.
# For Image 'Image5.jpgVasiliy_Kandinskiy_74.jpg' Mobile has the second largest score :0.10573895355479776.
#
# For Image 'Image5.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.4092095062803707.
# For Image 'Image5.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.23712920281834085.
#
# For Image 'Image5.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the largest score :0.4246696121631984.
# For Image 'Image5.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the second largest score :0.3935493343144456.
#
# For Image 'Image6.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.21178229409311444.
# For Image 'Image6.jpgVasiliy_Kandinskiy_2.jpg' VGG has the second largest score :0.1319735307019526.
#
# For Image 'Image6.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.27236700628712307.
# For Image 'Image6.jpgVasiliy_Kandinskiy_25.jpg' VGG has the second largest score :0.16808395092104644.
#
# For Image 'Image6.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.2692742263721937.
# For Image 'Image6.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.12463925766132308.
#
# For Image 'Image6.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.4345399482369291.
# For Image 'Image6.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.2840092079028266.
#
# For Image 'Image6.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the largest score :0.32056234007082557.
# For Image 'Image6.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the second largest score :0.31533428119733947.
#
# For Image 'Image7.jpgVasiliy_Kandinskiy_2.jpg' VGG has the largest score :0.1959514742061522.
# For Image 'Image7.jpgVasiliy_Kandinskiy_2.jpg' Mobile has the second largest score :0.19448220509693653.
#
# For Image 'Image7.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.131252122635285.
# For Image 'Image7.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.06724069146198268.
#
# For Image 'Image7.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.3166715925744166.
# For Image 'Image7.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.11207226910239763.
#
# For Image 'Image7.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.39544400755891307.
# For Image 'Image7.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.3501778837922721.
#
# For Image 'Image7.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the largest score :0.3057560636657983.
# For Image 'Image7.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the second largest score :0.29604572196454815.
#
# For Image 'Image8.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.297806408127897.
# For Image 'Image8.jpgVasiliy_Kandinskiy_2.jpg' VGG has the second largest score :0.09866649666071645.
#
# For Image 'Image8.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.3671761183930766.
# For Image 'Image8.jpgVasiliy_Kandinskiy_25.jpg' Mobile has the second largest score :0.10927670886636737.
#
# For Image 'Image8.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.21283256754958269.
# For Image 'Image8.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.101564778978261.
#
# For Image 'Image8.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.385814263033302.
# For Image 'Image8.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.24694469976849656.
#
# For Image 'Image8.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the largest score :0.3861787788572257.
# For Image 'Image8.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the second largest score :0.3843083710396077.
#
# For Image 'Image9.jpgVasiliy_Kandinskiy_2.jpg' Efficient has the largest score :0.26489553979842484.
# For Image 'Image9.jpgVasiliy_Kandinskiy_2.jpg' Mobile has the second largest score :0.10673274558858967.
#
# For Image 'Image9.jpgVasiliy_Kandinskiy_25.jpg' Efficient has the largest score :0.09434759486479222.
# For Image 'Image9.jpgVasiliy_Kandinskiy_25.jpg' VGG has the second largest score :0.0483912203707306.
#
# For Image 'Image9.jpgVasiliy_Kandinskiy_74.jpg' Efficient has the largest score :0.2719949993020451.
# For Image 'Image9.jpgVasiliy_Kandinskiy_74.jpg' VGG has the second largest score :0.12190824321377192.
#
# For Image 'Image9.jpgVasiliy_Kandinskiy_78.jpg' Efficient has the largest score :0.35747095132766904.
# For Image 'Image9.jpgVasiliy_Kandinskiy_78.jpg' Mobile has the second largest score :0.22285306458479504.
#
# For Image 'Image9.jpgVasiliy_Kandinskiy_9.jpg' Mobile has the largest score :0.32457540218325603.
# For Image 'Image9.jpgVasiliy_Kandinskiy_9.jpg' Efficient has the second largest score :0.29503148085360564.
